# %% [markdown]
# <div align="center">
# <img src='Pic/logo.png' width='200px'>
#
# # KHÓA HỌC: LẬP TRÌNH PYTHON CHO PHÂN TÍCH DỮ LIỆU VÀ HỌC MÁY
# ## BÀI 1: LẬP TRÌNH PYTHON CƠ BẢN (1)
#
# </div>
#
#
# ---
# Practice1: Lập trình Python cơ bản
# ---
#
# 1. Họ tên học viên: Nguyễn Anh Tú
# 2. Ngày sinh: 06/10/2006
# 3. Email: anhtunguyen6106@gmail.com

# %% [markdown]
# ## Bài 1: Chia kẹo cho học sinh lớp 1
# ----
# Cô có n cái kẹo, có m học sinh trong lớp. Hãy giúp cô chia đều số kẹo cho tất cả học sinh.
#
# **Yêu cầu:**
# * Nhập vào số kẹo của cô – N
# * Nhập vào số học sinh trong lớp – M
#
#
# Cho biết:
# 1. Mỗi học sinh được nhận bao nhiêu cái kẹo?
# 2. Cô còn lại bao nhiêu cái kẹo?

# %%
#{học viên viết code ở đây!}

N = int(input("Nhập số kẹo của cô: "))
M = int(input("Nhập số học sinh trong lớp: "))

print(f"Mỗi học sinh nhận được {N//M} cái kẹo.")
print(f"Cô còn lại {N%M} cái kẹo.")
# Out:
# Nhập số kẹo của cô: 10
# Nhập số học sinh trong lớp: 3
# Mỗi học sinh nhận được 3 cái kẹo.
# Cô còn lại 1 cái kẹo.

# %% [markdown]
# ## Bài 2: Tính tuổi
# ---
# Nhập vào tên và năm sinh của một người, tính tuổi của người đó và hiển thị ra màn hình thông báo
#
# Yêu cầu:
#
# * Nhập vào họ tên: mai phương thúy
# * Nhập vào năm sinh: 2000
#
# Hiển thị thông báo kết quả:
# 	 **Bạn “MAI PHƯƠNG THÚY” năm nay 21 tuổi!**

# %%
#{Học viên viết code ở đây!}

N = input("Nhập vào họ tên: ")
M = int(input("Nhập vào năm sinh: "))

print(f"Bạn \"{N}\" năm nay {2025-M} tuổi!")
# Out:
# Nhập vào họ tên: Nguyen Van A
# Nhập vào năm sinh: 2000
# Bạn "Nguyen Van A" năm nay 25 tuổi!

# %% [markdown]
# # Bài 3: Cho biết số thỏ trong rừng!
# ---
# Ban đầu trong rừng có một cặp thỏ, biết rằng cứ sau 1 tháng thì số lượng thỏ trong rừng tăng lên gấp đôi. Hỏi sau x tháng thì trong rừng có bao nhiêu con thỏ (Giả thiết các con thỏ không chết)
#
# Yêu cầu:
# * Nhập vào số tháng x:
# * Hiển thị kết quả số thỏ tương ứng sau x tháng:

# %%
#{Học viên viết code ở đây!}

x=int(input("Nhập vào số tháng x: "))

print(f"Hiển thị kết quả số thỏ tương ứng sau x tháng: {2**(x+1)}")
# Out:
# Nhập vào số tháng x: 3
# Hiển thị kết quả số thỏ tương ứng sau x tháng: 16

# %% [markdown]
# ## Bài 4.1: Chuỗi văn bản
# ---
#
# “Nước Việt Nam là một, dân tộc Việt Nam là một. Sông có thể cạn núi có thể mòn, song chân lý ấy không bao giờ thay đổi. (HỒ CHÍ MINH, 1890 – 1969)”
#
# Yêu cầu:
# 1. Cho biết số ký tự có trong đoạn văn trên.
# 2. Cho biết trong đoạn có chứa từ nào sau đây không (Không phân biệt chữ hoa, chữ thường)?
#     * “hồ chí minh”
#     * “non sông”
# 3. Tách đoạn văn thành các câu bởi dấu .
# 4. Cho biết trong đoạn văn trên có ký tự nào khác ký tự chữ và số hay không?
# 5. Thay thế các các từ ‘Việt Nam’ bằng ‘VIỆT NAM’ trong đoạn văn trên.

# %%
#{Học viên viết code ở đây!}

st= "Nước Việt Nam là một, dân tộc Việt Nam là một. Sông có thể cạn núi có thể mòn, song chân lý ấy không bao giờ thay đổi. (HỒ CHÍ MINH, 1890 – 1969)"

# %%
# Ý 1:
#{Học viên viết code ở đây!}

print(len(st))
# Out:
# 145

# %%
# Ý 2:
#{Học viên viết code ở đây!}

st_lower=st.lower()

st_1="hồ chí minh"

st_2="non sông"

print(f"Đoạn có chứa từ \"{st_1}\"" if st_1 in st_lower else f"Đoạn không chứa \"{st_1}\"")
print(f"Đoạn có chứa từ \"{st_2}\"" if st_2 in st_lower else f"Đoạn không chứa \"{st_2}\"")
# Out:
# Đoạn có chứa từ "hồ chí minh"
# Đoạn không chứa "non sông"

# %%
# Ý 3:
#{Học viên viết code ở đây!}

list_st = st.split(".")
for idx in range(len(list_st)):
    list_st[idx] = list_st[idx].strip()

print("Câu sau khi tách:")
print("\n".join(f"    Câu {i}: {s}." for i, s in enumerate(list_st, start=1)))
# Out:
# Câu sau khi tách:
#     Câu 1: Nước Việt Nam là một, dân tộc Việt Nam là một.
#     Câu 2: Sông có thể cạn núi có thể mòn, song chân lý ấy không bao giờ thay đổi.
#     Câu 3: (HỒ CHÍ MINH, 1890 – 1969).

# %%
# Ý 4:
#{Học viên viết code ở đây!}

special_chars = " ".join([ch for ch in st if not (ch.isalnum() or ch.isspace())])

print("Ký tự khác chữ và số trong đoạn văn:", special_chars if special_chars else "Đoạn văn chỉ có chữ và số")
# Out:
# Ký tự khác chữ và số trong đoạn văn: , . , . ( , – )

# %%
# Ý 5:
#{Học viên viết code ở đây!}

st_new = st.replace("Việt Nam", "VIỆT NAM")
print(st_new)
# Out:
# Nước VIỆT NAM là một, dân tộc VIỆT NAM là một. Sông có thể cạn núi có thể mòn, song chân lý ấy không bao giờ thay đổi. (HỒ CHÍ MINH, 1890 – 1969)

# %% [markdown]
# ## Bài 4.2: Chuẩn hóa chuỗi:
# ---
# Chuỗi st ban đầu: s = '   python FOR Machine LearNiNg      '
#
# **Yêu cầu:**
# 1. Chuẩn hóa chuỗi về chuỗi s1: Loại bỏ hết khoảng trắng ở đầu và cuối chuỗi , thêm ký tự ‘!’ ở cuối câu. chuyển hết về chữ thường và viết hoa ký tự đầu tiên trong mỗi từ: **'Python For Machine Learning!’**
#
# 2. Chuẩn hóa chuỗi về chuỗi s2: Loại bỏ hết khoảng trắng ở đầu và cuối chuỗi, chuyển toàn bộ sang chữ hoa và nối các từ bằng dấu ‘-’: **‘PYTHON-FOR-MACHINE-LEARNING'**

# %%
#{Học viên viết code ở đây!}

s = ' python FOR Machine LearNiNg '

# %%
#Ý 1:
s1 = s.strip().lower().title() + "!"
print(s1)
# Out:
# Python For Machine Learning!

# %%
#Ý 2:
s2 = "-".join(s.strip().upper().split())
print(s2)
# Out:
# PYTHON-FOR-MACHINE-LEARNING

# %% [markdown]
# ## Bài 5: Thống kê điểm Học viên
# ---
#
# Khởi tạo một danh sách gồm các điểm thi môn “Python for Analysis” của lớp VIN_01 (Điểm chữ: A, B, C, D, F)
#
# **Yêu cầu:**
# 1. Cho biết số sinh viên trong lớp
# 2. Có bao nhiêu sinh viên phải học lại môn này (điểm F).
# 3. Có bao nhiêu sinh viên có điểm từ B trở lên.
# 4. Sinh viên đầu tiên và cuối cùng trong lớp đã nghỉ học, tạo một bảng điểm mới và loại bỏ điểm của các sinh viên này ra

# %%
#{học viên viết code ở đây!}
#Khởi tạo danh sách
diem_python = ['C','B','D','A','F','A','B','F','B','B','C','A','D','F','B']

print('Bảng điểm Lập trình python:\n',diem_python)
# Out:
# Bảng điểm Lập trình python:
#  ['C', 'B', 'D', 'A', 'F', 'A', 'B', 'F', 'B', 'B', 'C', 'A', 'D', 'F', 'B']

# %%
#Ý 1:
print(f"Số sinh viên trong lớp: {len(diem_python)}")
# Out:
# Số sinh viên trong lớp: 15

# %%
#Ý 2:
print(f"Số sinh viên phải học lại môn này (điểm F): {diem_python.count("F")}")
# Out:
# Số sinh viên phải học lại môn này (điểm F): 3

# %%
#Ý 3:
print(f"Số sinh viên có điểm từ B trở lên: {diem_python.count("B")+diem_python.count("A")}")
# Out:
# Số sinh viên có điểm từ B trở lên: 8

# %%
#Ý 4:
del diem_python[-1], diem_python[0]

print(diem_python)
# Out:
# ['B', 'D', 'A', 'F', 'A', 'B', 'F', 'B', 'B', 'C', 'A', 'D', 'F']
